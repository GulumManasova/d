# %%
import pandas as pd 
df = pd.read_csv('data.csv')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
import pandas as pd 
df = pd.read_csv('data.csv')
print(df.iloc[2])
# Out:
# Duration     60.0
# Pulse       103.0
# Maxpulse    135.0
# Calories    340.0
# Name: 2, dtype: float64

# %%
import pandas as pd


df = pd.read_csv('data.csv')


print(df.iloc[0:5])
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
#Return a new Data Frame with no empty cells:
import pandas as pd
df=pd.read_csv("data.csv")
s=df.dropna()
print(s.to_string())
#Notice row 17,27 and other empty rows
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
#Replace NULL values with the number 1111111111
import pandas as pd

df = pd.read_csv('data.csv')

df.fillna(11111111, inplace = True)

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse    Calories
# 0          60    110       130       409.1
# 1          60    117       145       479.0
# 2          60    103       135       340.0
# 3          45    109       175       282.4
# 4          45    117       148       406.0
# 5          60    102       127       300.0
# 6          60    110       136       374.0
# 7          45    104       134       253.3
# 8          30    109       133       195.1
# 9          60     98       124       269.0
# 10         60    103       147       329.3
# 11         60    100       120       250.7
# 12         60    106       128       345.3
# 13         60    104       132       379.3
# 14         60     98       123       275.0
# 15         60     98       120       215.2
# 16         60    100       120       300.0
# 17         45     90       112  11111111.0
# 18         60    103       123       323.0
# 19         45     97       125       243.0
# 20         60    108       131       364.2
# ...

# %%
#Remove all rows with NULL values 
import pandas as pd

df = pd.read_csv('data.csv')

df.dropna(inplace = True)

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
#Replace NULL values in the "Calories" columns with the number 2222222 
import pandas as pd

df = pd.read_csv('data.csv')

df["Calories"].fillna(2222222, inplace = True)

print(df.to_string())

#This operati
# Out:
#      Duration  Pulse  Maxpulse   Calories
# 0          60    110       130      409.1
# 1          60    117       145      479.0
# 2          60    103       135      340.0
# 3          45    109       175      282.4
# 4          45    117       148      406.0
# 5          60    102       127      300.0
# 6          60    110       136      374.0
# 7          45    104       134      253.3
# 8          30    109       133      195.1
# 9          60     98       124      269.0
# 10         60    103       147      329.3
# 11         60    100       120      250.7
# 12         60    106       128      345.3
# 13         60    104       132      379.3
# 14         60     98       123      275.0
# 15         60     98       120      215.2
# 16         60    100       120      300.0
# 17         45     90       112  2222222.0
# 18         60    103       123      323.0
# 19         45     97       125      243.0
# 20         60    108       131      364.2
# ...

# %%
#Replacing Values
import pandas as pd

df = pd.read_csv('data.csv')

df.loc[5,'Duration'] = 333333

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5      333333    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
import pandas as pd

df = pd.read_csv('data.csv')

df['Calories'] = pd.to_datetime(df['Calories'])

df.dropna(subset=['Calories'], inplace = True)

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse                      Calories
# 0          60    110       130 1970-01-01 00:00:00.000000409
# 1          60    117       145 1970-01-01 00:00:00.000000479
# 2          60    103       135 1970-01-01 00:00:00.000000340
# 3          45    109       175 1970-01-01 00:00:00.000000282
# 4          45    117       148 1970-01-01 00:00:00.000000406
# 5          60    102       127 1970-01-01 00:00:00.000000300
# 6          60    110       136 1970-01-01 00:00:00.000000374
# 7          45    104       134 1970-01-01 00:00:00.000000253
# 8          30    109       133 1970-01-01 00:00:00.000000195
# 9          60     98       124 1970-01-01 00:00:00.000000269
# 10         60    103       147 1970-01-01 00:00:00.000000329
# 11         60    100       120 1970-01-01 00:00:00.000000250
# 12         60    106       128 1970-01-01 00:00:00.000000345
# 13         60    104       132 1970-01-01 00:00:00.000000379
# ...

# %%
import pandas as pd

df = pd.read_csv('data.csv')

for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.loc[x, "Duration"] = 44444

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
import pandas as pd

df = pd.read_csv('data.csv')

df.loc[5,'Duration'] = 1000

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5        1000    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
#Removing Rows
import pandas as pd

df = pd.read_csv('data.csv')

for x in df.index:
  if df.loc[x, "Duration"] > 100:
    df.drop(x, inplace = True)

#remember to include the 'inplace = True' argument to make the changes in the original DataFrame object instead of returning a copy

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
import pandas as pd

df = pd.read_csv('data.csv')

print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 169, dtype: bool

# %%
import pandas as pd

df = pd.read_csv('data.csv')

df['Calories'] = pd.to_datetime(df['Calories'])

df.dropna(subset=['Calories'], inplace = True)

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse                      Calories
# 0          60    110       130 1970-01-01 00:00:00.000000409
# 1          60    117       145 1970-01-01 00:00:00.000000479
# 2          60    103       135 1970-01-01 00:00:00.000000340
# 3          45    109       175 1970-01-01 00:00:00.000000282
# 4          45    117       148 1970-01-01 00:00:00.000000406
# 5          60    102       127 1970-01-01 00:00:00.000000300
# 6          60    110       136 1970-01-01 00:00:00.000000374
# 7          45    104       134 1970-01-01 00:00:00.000000253
# 8          30    109       133 1970-01-01 00:00:00.000000195
# 9          60     98       124 1970-01-01 00:00:00.000000269
# 10         60    103       147 1970-01-01 00:00:00.000000329
# 11         60    100       120 1970-01-01 00:00:00.000000250
# 12         60    106       128 1970-01-01 00:00:00.000000345
# 13         60    104       132 1970-01-01 00:00:00.000000379
# ...

# %%
#Mean = the average value
import pandas as pd

df = pd.read_csv('data.csv')

x = df["Calories"].mean()

df["Calories"].fillna(x, inplace = True)
print(df.to_string())
#mean 375.790244  in empty cells such as 17,27 and others
# Out:
#      Duration  Pulse  Maxpulse     Calories
# 0          60    110       130   409.100000
# 1          60    117       145   479.000000
# 2          60    103       135   340.000000
# 3          45    109       175   282.400000
# 4          45    117       148   406.000000
# 5          60    102       127   300.000000
# 6          60    110       136   374.000000
# 7          45    104       134   253.300000
# 8          30    109       133   195.100000
# 9          60     98       124   269.000000
# 10         60    103       147   329.300000
# 11         60    100       120   250.700000
# 12         60    106       128   345.300000
# 13         60    104       132   379.300000
# 14         60     98       123   275.000000
# 15         60     98       120   215.200000
# 16         60    100       120   300.000000
# 17         45     90       112   375.790244
# 18         60    103       123   323.000000
# 19         45     97       125   243.000000
# ...

# %%
#Median = the value in the middle
import pandas as pd

df = pd.read_csv('data.csv')

x = df["Calories"].median()

df["Calories"].fillna(x, inplace = True)

print(df.to_string())
#rows 17, 27 and other empty cells replaced with the median:318.6
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     318.6
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
#Mode = the value that appears most frequently
import pandas as pd

df = pd.read_csv('data.csv')

x = df["Calories"].mode()[0]

df["Calories"].fillna(x, inplace = True)

print(df.to_string())
#27 and 17 was empty and now they replaced with the mode: 300.0
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined
